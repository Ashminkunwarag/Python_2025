# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashminkunwarag/04_rcbd_2025/blob/main/Python_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First Program

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello", "My name is Ashmin Kunwar")
# Out:
# Hello My name is Ashmin Kunwar

# %% [markdown]
# Variable: It is a name given to the memory location in a program.
# For example: name= "Ashmin", age=26 and price=45.67

# %%
name="Ashmin"
age=26
price=55.67
a=None
print(name)
print(age)
print(price)
print(a)
# Out:
# Ashmin
# 26
# 55.67
# None

# %% [markdown]
# Data Types:
# Integer, Float, String, Boolean, None

# %%
print(type(name))
print(type(age))
print(type(price))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'NoneType'>

# %% [markdown]
# Keywords: Reserved words in Python. Example: True, False, and None.
# Python is a case-sensitive language.

# %%
# Print Sum
# Arithmetic Operator Example
a=5
b=7
sum=a+b
print(sum)
print(b%a)
# Out:
# 12
# 2

# %% [markdown]
# Comments: Using "#" or '''.

# %% [markdown]
# Operators: It is a symbol that performs a certain operation between operands.
# Types:
# 1. Arithmetic Operators
# 2. Relational / Comparison Operators
# 3. Assignment Operators
# 4. Logical Operators

# %%
# Relational Operators
a=50
b=55
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Assignment Operators
num=50
num=num+50
print(num)
num2=5
num2 **=5
print("num2:",num2)
# Out:
# False
# True
# False
# True
# 100
# num2: 3125

# %%
c=5
print(not 5)
# Out:
# False
